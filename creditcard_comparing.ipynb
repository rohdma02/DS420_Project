# %% [markdown]
# # Compare Algorithms/Conclusions
#
# ##### Authors: Cody, Mateus, and Mughees
# ##### Step 5: Compare Algorithms

# %% [markdown]
# After comparing the performance on the machine learning algorithms Random Forest, K-nearest Neighbors, and Decision Tree, we analyze the best scores and the best hyperparameters to determine which algorithm performs the best for the Credit Card dataset.
#
# The results for each algorithm are in order first to last.
#
# Random Forest Algorithm
# Best Score: 0.9998593111156395
# Best Hyperparameters:
# criterion: 'gini'
# max_depth: None
# max_features: 'sqrt'
# min_samples_leaf: 1
# min_samples_split: 2
# n_estimators: 50
#
# K-Nearest Neighbors Algorithm
# Best Score: 0.9981487259490379
# Best Hyperparameters:
# algorithm: 'auto'
# leaf_size: 10
# n_neighbors: 3
# p: 1
# weights: 'uniform'
#
# Decision Tree Algorithm
# Best Score: 0.9299104855201996
# Best Hyperparameters:
# criterion: 'entropy'
# max_depth: 1
# min_samples_leaf: 1
# min_samples_split: 2
# min_weight_fraction_leaf: 0.0
# splitter: 'best'

# %% [markdown]
# import matplotlib.pyplot as plt
#
# algorithms = ['Random Forest', 'K-Nearest Neighbors', 'Decision Tree']
# best_scores = [0.9998593111156395, 0.9981487259490379, 0.9299104855201996]
#
# plt.figure(figsize=(8, 6))
# plt.bar(algorithms, best_scores)
# plt.ylim(0.9, 1.0)
# plt.xlabel('Algorithms')
# plt.ylabel('Best Score')
# plt.title('Comparison of Best Scores')
# plt.show()

# %%
import matplotlib.pyplot as plt

algorithms = ['Random Forest', 'K-Nearest Neighbors', 'Decision Tree']
best_scores = [0.9998593111156395, 0.9981487259490379, 0.9299104855201996]

plt.figure(figsize=(8, 6))
plt.bar(algorithms, best_scores)
plt.ylim(0.9, 1.0)
plt.xlabel('Algorithms')
plt.ylabel('Best Score')
plt.title('Comparison of Best Scores')
plt.show()

# %% [markdown]
# Add more if yall want
